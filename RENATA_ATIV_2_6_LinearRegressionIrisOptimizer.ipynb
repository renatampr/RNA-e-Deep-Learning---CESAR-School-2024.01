# %% [markdown]
# <a href="https://colab.research.google.com/github/renatampr/RNA-e-Deep-Learning---CESAR-School-2024.01/blob/main/RENATA_ATIV_2_6_LinearRegressionIrisOptimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regressão Linear com PyTorch

# %% [markdown]
# ## Objetivos

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se:
# - a função de perda MSE do PyTorch,
# - treinamento dos parâmetros via gradiente descendente usando o otimizador.
# - A rede é criada com uma camada nn.Linear()

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import torch
from torch import nn, optim
from torch.autograd import Variable
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

torch.manual_seed(1234)

# %% [markdown]
# ## Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1].astype(np.float32)
y_train = data[:,1:2].astype(np.float32)

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float32
# y_train.shape: (50, 1) float32
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias = torch.FloatTensor(x_train_bias)
y_train      = torch.FloatTensor(y_train)

# %% [markdown]
# ## Criação do modelo da rede

# %%
model = torch.nn.Linear(2, 1, bias=False)

# %% [markdown]
# ### Verificando a inicialização dos parâmetros

# %%
model.weight.data = torch.zeros(1,2)
torch.nn.init.uniform(model.weight.data, -0.1, 0.1)
model.weight.data
# Out:
# <ipython-input-9-e458ff4bc28e>:2: FutureWarning: `nn.init.uniform` is now deprecated in favor of `nn.init.uniform_`.
#   torch.nn.init.uniform(model.weight.data, -0.1, 0.1)
# tensor([[-0.0480, -0.0267]])

# %% [markdown]
# ### Testando o predict da rede

# %%
model(Variable(torch.ones((5,2))))
# Out:
# tensor([[-0.0747],
#         [-0.0747],
#         [-0.0747],
#         [-0.0747],
#         [-0.0747]], grad_fn=<MmBackward0>)

# %% [markdown]
# ## Treinamento

# %% [markdown]
# ### Definindo função de perda e otimizador

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.3)

# %% [markdown]
# ### Laço de treinamento

# %%
num_epochs = 200
best_epoch_weight = None
best_epoch_number = 0
best_epoch_loss = criterion(model(Variable(x_train_bias)), Variable(y_train))
w0_list = []
w1_list = []
for epoch in range(num_epochs):
    inputs = Variable(x_train_bias)
    target = Variable(y_train)

    # forward - predict
    out = model(inputs)

    w0_list.append(model.weight.data[0][0].item())
    w1_list.append(model.weight.data[0][1].item())

    #loss cálculo da função de perda
    loss = criterion(out, target)

    # backward e otimizador
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (loss < best_epoch_loss):
        best_epoch_loss = loss
        best_epoch_weight = model.state_dict()
        best_epoch_number = epoch + 1

    # verbose
    if (epoch+1) % 20 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss.data))
# Out:
# Epoch[20/200], loss: 0.021173
# Epoch[40/200], loss: 0.021171
# Epoch[60/200], loss: 0.021170
# Epoch[80/200], loss: 0.021170
# Epoch[100/200], loss: 0.021169
# Epoch[120/200], loss: 0.021169
# Epoch[140/200], loss: 0.021169
# Epoch[160/200], loss: 0.021169
# Epoch[180/200], loss: 0.021169
# Epoch[200/200], loss: 0.021169

# %%
print(best_epoch_number)
print(best_epoch_loss)
print(best_epoch_weight)
# Out:
# 168
# tensor(0.0212, grad_fn=<MseLossBackward0>)
# OrderedDict([('weight', tensor([[0.2614, 0.6864]]))])

# %% [markdown]
# ## Avaliação

# %%
y_pred = model(Variable(x_train_bias))
plt.plot(x_train, y_train.numpy(), 'ro', label='Original data')
plt.plot(x_train, y_pred.data.numpy(), 'kx-', label='Fitting Line')
plt.show()

# %% [markdown]
# # Exercícios

# %% [markdown]
# - 1) Calcule o valor da função de custo (MSE) depois da rede treinada, utilizando a
#    função `criterion` utilizada no laço de treinamento.

# %%
#todo

y_pred_treinada = model(Variable(x_train_bias))
loss_treinada = criterion(y_pred_treinada, Variable(y_train))
print(loss_treinada)
# Out:
# tensor(0.0212, grad_fn=<MseLossBackward0>)

# %% [markdown]
# <details>
# <summary>Mostrar Resultado</summary>
#
# ```python
# y_pred = model(Variable(x_train_bias))
# loss = criterion(y_pred, Variable(y_train))
# print(loss)
# ```
#
# </details>

# %% [markdown]
# - 2) Faça igual o exercício do notebook anterior, de plotar um gráfico scatterplot para
#    mostrar a evolução dos parâmetros durante o treinamento pelo gradiente descendente.

# %% [markdown]
# <details>
# <summary>Mostrar Resultado</summary>
#
# ```python
# plt.scatter(w0_list,w1_list)
# w0_old = None
# for (w0,w1) in zip(w0_list,w1_list):
#     if w0_old:
#         plt.arrow(w0_old, w1_old, w0-w0_old, w1-w1_old,
#                   head_length=0.01,head_width=0.01,shape='full',
#                   length_includes_head=True)
#     w0_old,w1_old = w0,w1
# ```
#
# </details>

# %%
# Exercício 2

plt.scatter(w0_list,w1_list)
w0_old = None
for (w0,w1) in zip(w0_list,w1_list):
    if w0_old:
        plt.arrow(w0_old, w1_old, w0-w0_old, w1-w1_old,
                  head_length=0.01,head_width=0.01,shape='full',
                  length_includes_head=True)
    w0_old,w1_old = w0,w1

# %% [markdown]
# # Aprendizados
